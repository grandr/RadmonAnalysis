# %%
import os, sys
sys.path.append("../Radmon2Fill/")
import ROOT
#import rootnotes
#import rootprint
import radmonFills

# %%
from radmonFills import *
f = RadmonFills()
from ROOT import TFile

# %%
f.init(4479)

# %%
#%%rootprint
#c = rootnotes.canvas("Rate", (800, 400))
f.drawRate(5)
# Out:
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: hrate5 (Potential memory leak).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-6fa8cffde195> in <module>()
#       1 #%%rootprint
#       2 #c = rootnotes.canvas("Rate", (800, 400))
# ----> 3 f.drawRate(5)
#
# /home/grandr/cms/Bril/RadmonAnalysis/Radmon2Fill/radmonFills.pyc in drawRate(self, indx)
#      71
#      72         tree = self.f.Get("t")
# ---> 73         for i in range(0, tree.GetEntries()) :
#      74             nb = tree.GetEntry(i)
#      75             if nb < 0:
#
# AttributeError: 'TObject' object has no attribute 'GetEntries'

# %%
# %%rootprint
# c2 = rootnotes.canvas("Running Sum 5 min", (800, 400))
# f.drawRunningSum(5,5)
# Out:
# ERROR: Cell magic `%%rootprint` not found.

# %%
c2
# Out:
# <ROOT.TCanvas object ("Running Sum 5 min") at 0x5625d9f15b70>

# %%
# %%rootprint
# c3 = rootnotes.canvas("Running Sum 15 min", (800, 400))
# f.drawRunningSum(5,15)
# Out:
# TFile::Append:0: RuntimeWarning: Replacing existing TH1: hrsum5 (Potential memory leak).

# %%
c3
# Out:
# <ROOT.TCanvas object ("Running Sum 15 min") at 0x5625d7371a60>

# %%
# %%rootprint
# c4 = rootnotes.canvas("Running Sum 30 min", (800, 400))
# f.drawRunningSum(5,30)
# Out:
# TFile::Append:0: RuntimeWarning: Replacing existing TH1: hrsum5 (Potential memory leak).

# %%
c4
# Out:
# <ROOT.TCanvas object ("Running Sum 30 min") at 0x5625d9f18770>
